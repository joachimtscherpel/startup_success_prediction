# %%
import pandas as pd

# %%
benelux = pd.read_csv('data/dr/raw/2015_Belgium_Netherlands.csv')
denfin = pd.read_csv('data/dr/raw/2015_Denmark_Finland.csv')
swenor = pd.read_csv('data/dr/raw/2015_Sweden_Norway.csv')
germany_1 = pd.read_csv('data/dr/raw/2015-2020_Germany.csv')
germany_2 = pd.read_csv('data/dr/raw/2021_Germany.csv')

# %%
dr = pd.concat([benelux, denfin, swenor, germany_1, germany_2], ignore_index=True)

# %%
dr.to_pickle('data/dr/raw/dr_raw.pkl')
